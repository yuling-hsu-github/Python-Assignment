# %% [markdown]
# <a id='section_id0'></a>
# # BMIS-2542: Data Programming Essentials *with Python*
# ##### Katz Graduate School of Business, University of Pittsburgh
#
# ## Classroom Exercise 1: Introduction and getting started with Python
#
# ***
# <font color="#740202">**List of Session-1 Exercises:**
#
# (1) [Using Markdown and HTML](#section_id-ex1), (2) [Getting user input](#section_id-ex2), (3) [Using conditional logic](#section_id-ex3), and (4) [Using functions and exception handling](#section_id-ex4)

# %% [markdown]
# ***
# <a id='section_id-ex1'></a>
# ### <span style="background-color:#CCFFCC">Class Exercise-1: Markdown and HTML</span>
# * Insert a new markdown cell in the notebook and type in the header "Exercise-1".
# * In a new Markdown cell, type your name and email information in "bullet point" format.
# ***
# <div style="text-align: right"> <a href='#section_id0'>Back to top of Notebook</a></div>

# %% [markdown]
# Exercise-1

# %%
print("Yuling Hsu")
print("YUH162@pitt.edu")
# Out:
# Hao-Yi Chen
# HAC215@pitt.edu

# %% [markdown]
# ***
# <a id='section_id-ex2'></a>
# ### <span style="background-color:#CCFFCC">Class Exercise-2: User input</span>
# * Insert a new markdown cell in the notebook and type in the header "Exercise-2".
# * Create a python program to accomplish the following:
#     * Get three numbers from the user as input to the program
#     * Find the average of the three numbers
#     * Display the average of the three numbers to the user
# ***
# <div style="text-align: right"> <a href='#section_id0'>Back to top of Notebook</a></div>

# %% [markdown]
# Exercise-2

# %%
x,y,z=input("enter three numbers").split(',')
# Out:
# enter three numbers1,2,3

# %%
x
# Out:
# '1'

# %%
float(x)
# Out:
# 1.0

# %%
float(y)
# Out:
# 2.0

# %%
 float(z)
# Out:
# 3.0

# %%
average=(float(x)+float(y)+float(z))/3
print(average)
# Out:
# 2.0

# %%
ler

# %% [markdown]
# ***
# <a id='section_id-ex3'></a>
# ### <span style="background-color:#CCFFCC">Class Exercise-3: Conditional logic</span>
# * Insert a new markdown cell in the notebook and type in the header "Exercise-3".
# * Create a python program to accomplish the following:
#     * Get three numbers from the user as input to the program
#     * Check if the user has entered duplicate numbers
#     * If the user has entered duplicates, alert the user and replace the duplicate(s)
#     * Once you have three distinct numbers, find the average of the three numbers and display the average of the three numbers to the user
# ***
# <div style="text-align: right"> <a href='#section_id0'>Back to top of Notebook</a></div>

# %% [markdown]
# Exercise-3

# %%
x,y,z=input("enter three numbers separated by commas").split(',')
while x==y or y==z or z==x:
   x,y,z = input("enter three distinct numbers separated by commas").split(',')
# Out:
# enter three numbers separated by commas1,2,3

# %%
float(x)
# Out:
# 1.0

# %%
float (y)
# Out:
# 2.0

# %%
float (z)
# Out:
# 3.0

# %%
average = (float(x)+float(y)+float(z))/3
print(average)
# Out:
# 2.0

# %% [markdown]
# ***
# <a id='section_id-ex4'></a>
# ### <span style="background-color:#CCFFCC">Class Exercise-4: Using Functions</span>
# * Insert a new markdown cell in the notebook and type in the header "Exercise-4".
# * Create a python program to accomplish the following:
#     * Write three functions:
#         * First: to get three numbers from the user as input to the program
#         * Second: to check if the user has entered duplicate numbers, alert the user, and replace duplicate(s) with distinct numbers
#         * Third: find the average of the three numbers and display the average of the three numbers to the user
#     * Using the above three functions, create a Python program to receive three unique numbers from a user, calculate the average, and display the calculated average to the user. Use exception handling wherever you see fit and show intuitive error messages to the user
# ***

# %% [markdown]
# Exercise-4

# %%
def myfun():
  x,y,z = input("enter three numbers separated by commas").split(',')
  x = float(x)
  y = float(y)
  z = float(z)
  return x,y,z

# %%
def checking_duplicate(x,y,z):
  while x==y or y==z or z==x:
   x,y,z = input("enter three distinct numbers separated by commas").split(',')
  x = float(x)
  y = float(y)
  z = float(z)
  return x,y,z

# %%
def average_function(x,y,z):
  x = float(x)
  y= float(y)
  z= float(z)
  average = (x+y+z)/3
  return x,y,z,average

# %%
x,y,z=myfun()
x,y,z=checking_duplicate(x,y,z)
x,y,z,average = average_function(x,y,z)
print("x:",x)
print("y:",y)
print("z:",z)
print("average:",average)
# Out:
# enter three numbers separated by commas2,2,4
# enter three distinct numbers separated by commas3,4,5
# x: 3.0
# y: 4.0
# z: 5.0
# average: 4.0
